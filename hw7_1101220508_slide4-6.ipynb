# %% [markdown]
# NAME : NUR AUFA, STUDENT ID : 1101220508, SLIDE 4-6

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.signal import butter, filtfilt

# %%
sn = pd.read_csv('1.csv')
print(f'Nama Kolom: {sn.columns}')
# Out:
# Nama Kolom: Index(['0', '1502', '2215', '2153', '1'], dtype='object')

# %%
#Memilih kolom yang sesuai dengan dataset
x_data = sn['1502']  
y_data = sn['2215']  
z_data = sn['2153']  

#Mmenerapkan low-pass dan high-pass filter
def butter_filter(data, cutoff, fs, btype='low'):
    nyquist = 0.5 * fs
    normal_cutoff = cutoff / nyquist
    b, a = butter(1, normal_cutoff, btype=btype, analog=False)
    return filtfilt(b, a, data)

#Frekuensi sampling dan frekuensi cutoff 
fs = 1000  
cutoff = 1  

#Menerapkan filter pada setiap data
x_b = x_data
x_dc = butter_filter(x_b, cutoff, fs, btype='low')  
x_ac = butter_filter(x_b, cutoff, fs, btype='high')  

y_b = y_data
y_dc = butter_filter(y_b, cutoff, fs, btype='low')
y_ac = butter_filter(y_b, cutoff, fs, btype='high')

z_b = z_data
z_dc = butter_filter(z_b, cutoff, fs, btype='low')
z_ac = butter_filter(z_b, cutoff, fs, btype='high')

# %%
#Plotting hasil analisis
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 5))

#Plot untuk x data
ax1.plot(x_b, label='x_b (No Filter)')
ax1.plot(x_dc, label='x_dc (Low-pass)', linestyle='--')
ax1.plot(x_ac, label='x_ac (High-pass)', linestyle=':')
ax1.set_title('x Time Series')
ax1.legend()

#Plot untuk y data
ax2.plot(y_b, label='y_b (No Filter)')
ax2.plot(y_dc, label='y_dc (Low-pass)', linestyle='--')
ax2.plot(y_ac, label='y_ac (High-pass)', linestyle=':')
ax2.set_title('y Time Series')
ax2.legend()

#Plot untuk z data
ax3.plot(z_b, label='z_b (No Filter)')
ax3.plot(z_dc, label='z_dc (Low-pass)', linestyle='--')
ax3.plot(z_ac, label='z_ac (High-pass)', linestyle=':')
ax3.set_title('z Time Series')
ax3.legend()

plt.tight_layout()
plt.show()

# %%
#Menyimpan hasil ke dalam CSV (untuk setiap time series)
header = 'Time, x_b, x_dc, x_ac, y_b, y_dc, y_ac, z_b, z_dc, z_ac'

#Menggabungkan data dalam satu file CSV
output_data = pd.DataFrame({
    'Time': np.arange(len(x_data)),  # Waktu dalam bentuk indeks
    'x_b': x_b, 'x_dc': x_dc, 'x_ac': x_ac,
    'y_b': y_b, 'y_dc': y_dc, 'y_ac': y_ac,
    'z_b': z_b, 'z_dc': z_dc, 'z_ac': z_ac
})

#Menyimpan ke dalam file CSV
output_data.to_csv(r'D:\Output HW 7 Slide 4-6\1.csv', index=False, header=True)

# %%
sn = pd.read_csv('2.csv')
print(f'Nama Kolom: {sn.columns}')
# Out:
# Nama Kolom: Index(['0', '1984', '1998', '1645', '1'], dtype='object')

# %%
#Memilih kolom yang sesuai dengan dataset
x_data = sn['1984']  
y_data = sn['1998']  
z_data = sn['1645']  

#Mmenerapkan low-pass dan high-pass filter
def butter_filter(data, cutoff, fs, btype='low'):
    nyquist = 0.5 * fs
    normal_cutoff = cutoff / nyquist
    b, a = butter(1, normal_cutoff, btype=btype, analog=False)
    return filtfilt(b, a, data)

#Frekuensi sampling dan frekuensi cutoff 
fs = 1000  
cutoff = 1  

#Menerapkan filter pada setiap data
x_b = x_data
x_dc = butter_filter(x_b, cutoff, fs, btype='low')  
x_ac = butter_filter(x_b, cutoff, fs, btype='high')  

y_b = y_data
y_dc = butter_filter(y_b, cutoff, fs, btype='low')
y_ac = butter_filter(y_b, cutoff, fs, btype='high')

z_b = z_data
z_dc = butter_filter(z_b, cutoff, fs, btype='low')
z_ac = butter_filter(z_b, cutoff, fs, btype='high')

#Plotting hasil analisis
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 5))

#Plot untuk x data
ax1.plot(x_b, label='x_b (No Filter)')
ax1.plot(x_dc, label='x_dc (Low-pass)', linestyle='--')
ax1.plot(x_ac, label='x_ac (High-pass)', linestyle=':')
ax1.set_title('x Time Series')
ax1.legend()

#Plot untuk y data
ax2.plot(y_b, label='y_b (No Filter)')
ax2.plot(y_dc, label='y_dc (Low-pass)', linestyle='--')
ax2.plot(y_ac, label='y_ac (High-pass)', linestyle=':')
ax2.set_title('y Time Series')
ax2.legend()

#Plot untuk z data
ax3.plot(z_b, label='z_b (No Filter)')
ax3.plot(z_dc, label='z_dc (Low-pass)', linestyle='--')
ax3.plot(z_ac, label='z_ac (High-pass)', linestyle=':')
ax3.set_title('z Time Series')
ax3.legend()

plt.tight_layout()
plt.show()

#Menyimpan hasil ke dalam CSV (untuk setiap time series)
header = 'Time, x_b, x_dc, x_ac, y_b, y_dc, y_ac, z_b, z_dc, z_ac'

#Menggabungkan data dalam satu file CSV
output_data = pd.DataFrame({
    'Time': np.arange(len(x_data)),  # Waktu dalam bentuk indeks
    'x_b': x_b, 'x_dc': x_dc, 'x_ac': x_ac,
    'y_b': y_b, 'y_dc': y_dc, 'y_ac': y_ac,
    'z_b': z_b, 'z_dc': z_dc, 'z_ac': z_ac
})

#Menyimpan ke dalam file CSV
output_data.to_csv(r'D:\Output HW 7 Slide 4-6\2.csv', index=False, header=True)

# %%
sn = pd.read_csv('3.csv')
print(f'Nama Kolom: {sn.columns}')
# Out:
# Nama Kolom: Index(['0', '1928', '2382', '1943', '1'], dtype='object')

# %%
#Memilih kolom yang sesuai dengan dataset
x_data = sn['1928']  
y_data = sn['2382']  
z_data = sn['1943']  

#Mmenerapkan low-pass dan high-pass filter
def butter_filter(data, cutoff, fs, btype='low'):
    nyquist = 0.5 * fs
    normal_cutoff = cutoff / nyquist
    b, a = butter(1, normal_cutoff, btype=btype, analog=False)
    return filtfilt(b, a, data)

#Frekuensi sampling dan frekuensi cutoff 
fs = 1000  
cutoff = 1  

#Menerapkan filter pada setiap data
x_b = x_data
x_dc = butter_filter(x_b, cutoff, fs, btype='low')  
x_ac = butter_filter(x_b, cutoff, fs, btype='high')  

y_b = y_data
y_dc = butter_filter(y_b, cutoff, fs, btype='low')
y_ac = butter_filter(y_b, cutoff, fs, btype='high')

z_b = z_data
z_dc = butter_filter(z_b, cutoff, fs, btype='low')
z_ac = butter_filter(z_b, cutoff, fs, btype='high')

#Plotting hasil analisis
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 5))

#Plot untuk x data
ax1.plot(x_b, label='x_b (No Filter)')
ax1.plot(x_dc, label='x_dc (Low-pass)', linestyle='--')
ax1.plot(x_ac, label='x_ac (High-pass)', linestyle=':')
ax1.set_title('x Time Series')
ax1.legend()

#Plot untuk y data
ax2.plot(y_b, label='y_b (No Filter)')
ax2.plot(y_dc, label='y_dc (Low-pass)', linestyle='--')
ax2.plot(y_ac, label='y_ac (High-pass)', linestyle=':')
ax2.set_title('y Time Series')
ax2.legend()

#Plot untuk z data
ax3.plot(z_b, label='z_b (No Filter)')
ax3.plot(z_dc, label='z_dc (Low-pass)', linestyle='--')
ax3.plot(z_ac, label='z_ac (High-pass)', linestyle=':')
ax3.set_title('z Time Series')
ax3.legend()

plt.tight_layout()
plt.show()

#Menyimpan hasil ke dalam CSV (untuk setiap time series)
header = 'Time, x_b, x_dc, x_ac, y_b, y_dc, y_ac, z_b, z_dc, z_ac'

#Menggabungkan data dalam satu file CSV
output_data = pd.DataFrame({
    'Time': np.arange(len(x_data)),  # Waktu dalam bentuk indeks
    'x_b': x_b, 'x_dc': x_dc, 'x_ac': x_ac,
    'y_b': y_b, 'y_dc': y_dc, 'y_ac': y_ac,
    'z_b': z_b, 'z_dc': z_dc, 'z_ac': z_ac
})

#Menyimpan ke dalam file CSV
output_data.to_csv(r'D:\Output HW 7 Slide 4-6\3.csv', index=False, header=True)

# %%
sn = pd.read_csv('4.csv')
print(f'Nama Kolom: {sn.columns}')
# Out:
# Nama Kolom: Index(['0', '2045', '2326', '1833', '1'], dtype='object')

# %%
#Memilih kolom yang sesuai dengan dataset
x_data = sn['2045']  
y_data = sn['2326']  
z_data = sn['1833']  

#Mmenerapkan low-pass dan high-pass filter
def butter_filter(data, cutoff, fs, btype='low'):
    nyquist = 0.5 * fs
    normal_cutoff = cutoff / nyquist
    b, a = butter(1, normal_cutoff, btype=btype, analog=False)
    return filtfilt(b, a, data)

#Frekuensi sampling dan frekuensi cutoff 
fs = 1000  
cutoff = 1  

#Menerapkan filter pada setiap data
x_b = x_data
x_dc = butter_filter(x_b, cutoff, fs, btype='low')  
x_ac = butter_filter(x_b, cutoff, fs, btype='high')  

y_b = y_data
y_dc = butter_filter(y_b, cutoff, fs, btype='low')
y_ac = butter_filter(y_b, cutoff, fs, btype='high')

z_b = z_data
z_dc = butter_filter(z_b, cutoff, fs, btype='low')
z_ac = butter_filter(z_b, cutoff, fs, btype='high')

#Plotting hasil analisis
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 5))
#Plot untuk x data
ax1.plot(x_b, label='x_b (No Filter)')
ax1.plot(x_dc, label='x_dc (Low-pass)', linestyle='--')
ax1.plot(x_ac, label='x_ac (High-pass)', linestyle=':')
ax1.set_title('x Time Series')
ax1.legend()

#Plot untuk y data
ax2.plot(y_b, label='y_b (No Filter)')
ax2.plot(y_dc, label='y_dc (Low-pass)', linestyle='--')
ax2.plot(y_ac, label='y_ac (High-pass)', linestyle=':')
ax2.set_title('y Time Series')
ax2.legend()

#Plot untuk z data
ax3.plot(z_b, label='z_b (No Filter)')
ax3.plot(z_dc, label='z_dc (Low-pass)', linestyle='--')
ax3.plot(z_ac, label='z_ac (High-pass)', linestyle=':')
ax3.set_title('z Time Series')
ax3.legend()

plt.tight_layout()
plt.show()

#Menyimpan hasil ke dalam CSV (untuk setiap time series)
header = 'Time, x_b, x_dc, x_ac, y_b, y_dc, y_ac, z_b, z_dc, z_ac'

#Menggabungkan data dalam satu file CSV
output_data = pd.DataFrame({
    'Time': np.arange(len(x_data)),  # Waktu dalam bentuk indeks
    'x_b': x_b, 'x_dc': x_dc, 'x_ac': x_ac,
    'y_b': y_b, 'y_dc': y_dc, 'y_ac': y_ac,
    'z_b': z_b, 'z_dc': z_dc, 'z_ac': z_ac
})
#Menyimpan ke dalam file CSV
output_data.to_csv(r'D:\Output HW 7 Slide 4-6\4.csv', index=False, header=True)

# %%
sn = pd.read_csv('5.csv')
print(f'Nama Kolom: {sn.columns}')
# Out:
# Nama Kolom: Index(['0', '1915', '2337', '1906', '1'], dtype='object')

# %%
#Memilih kolom yang sesuai dengan dataset
x_data = sn['1915']  
y_data = sn['2337']  
z_data = sn['1906']  

#Mmenerapkan low-pass dan high-pass filter
def butter_filter(data, cutoff, fs, btype='low'):
    nyquist = 0.5 * fs
    normal_cutoff = cutoff / nyquist
    b, a = butter(1, normal_cutoff, btype=btype, analog=False)
    return filtfilt(b, a, data)

#Frekuensi sampling dan frekuensi cutoff 
fs = 1000  
cutoff = 1  

#Menerapkan filter pada setiap data
x_b = x_data
x_dc = butter_filter(x_b, cutoff, fs, btype='low')  
x_ac = butter_filter(x_b, cutoff, fs, btype='high')  

y_b = y_data
y_dc = butter_filter(y_b, cutoff, fs, btype='low')
y_ac = butter_filter(y_b, cutoff, fs, btype='high')

z_b = z_data
z_dc = butter_filter(z_b, cutoff, fs, btype='low')
z_ac = butter_filter(z_b, cutoff, fs, btype='high')

#Plotting hasil analisis
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 5))
#Plot untuk x data
ax1.plot(x_b, label='x_b (No Filter)')
ax1.plot(x_dc, label='x_dc (Low-pass)', linestyle='--')
ax1.plot(x_ac, label='x_ac (High-pass)', linestyle=':')
ax1.set_title('x Time Series')
ax1.legend()

#Plot untuk y data
ax2.plot(y_b, label='y_b (No Filter)')
ax2.plot(y_dc, label='y_dc (Low-pass)', linestyle='--')
ax2.plot(y_ac, label='y_ac (High-pass)', linestyle=':')
ax2.set_title('y Time Series')
ax2.legend()

#Plot untuk z data
ax3.plot(z_b, label='z_b (No Filter)')
ax3.plot(z_dc, label='z_dc (Low-pass)', linestyle='--')
ax3.plot(z_ac, label='z_ac (High-pass)', linestyle=':')
ax3.set_title('z Time Series')
ax3.legend()

plt.tight_layout()
plt.show()

#Menyimpan hasil ke dalam CSV (untuk setiap time series)
header = 'Time, x_b, x_dc, x_ac, y_b, y_dc, y_ac, z_b, z_dc, z_ac'

#Menggabungkan data dalam satu file CSV
output_data = pd.DataFrame({
    'Time': np.arange(len(x_data)),  # Waktu dalam bentuk indeks
    'x_b': x_b, 'x_dc': x_dc, 'x_ac': x_ac,
    'y_b': y_b, 'y_dc': y_dc, 'y_ac': y_ac,
    'z_b': z_b, 'z_dc': z_dc, 'z_ac': z_ac
})
#Menyimpan ke dalam file CSV
output_data.to_csv(r'D:\Output HW 7 Slide 4-6\5.csv', index=False, header=True)

# %%
sn = pd.read_csv('6.csv')
print(f'Nama Kolom: {sn.columns}')
# Out:
# Nama Kolom: Index(['0', '1953', '1979', '1629', '1'], dtype='object')

# %%
#Memilih kolom yang sesuai dengan dataset
x_data = sn['1953']  
y_data = sn['1979']  
z_data = sn['1629']  

#Mmenerapkan low-pass dan high-pass filter
def butter_filter(data, cutoff, fs, btype='low'):
    nyquist = 0.5 * fs
    normal_cutoff = cutoff / nyquist
    b, a = butter(1, normal_cutoff, btype=btype, analog=False)
    return filtfilt(b, a, data)

#Frekuensi sampling dan frekuensi cutoff 
fs = 1000  
cutoff = 1  

#Menerapkan filter pada setiap data
x_b = x_data
x_dc = butter_filter(x_b, cutoff, fs, btype='low')  
x_ac = butter_filter(x_b, cutoff, fs, btype='high')  

y_b = y_data
y_dc = butter_filter(y_b, cutoff, fs, btype='low')
y_ac = butter_filter(y_b, cutoff, fs, btype='high')

z_b = z_data
z_dc = butter_filter(z_b, cutoff, fs, btype='low')
z_ac = butter_filter(z_b, cutoff, fs, btype='high')

#Plotting hasil analisis
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 5))
#Plot untuk x data
ax1.plot(x_b, label='x_b (No Filter)')
ax1.plot(x_dc, label='x_dc (Low-pass)', linestyle='--')
ax1.plot(x_ac, label='x_ac (High-pass)', linestyle=':')
ax1.set_title('x Time Series')
ax1.legend()

#Plot untuk y data
ax2.plot(y_b, label='y_b (No Filter)')
ax2.plot(y_dc, label='y_dc (Low-pass)', linestyle='--')
ax2.plot(y_ac, label='y_ac (High-pass)', linestyle=':')
ax2.set_title('y Time Series')
ax2.legend()

#Plot untuk z data
ax3.plot(z_b, label='z_b (No Filter)')
ax3.plot(z_dc, label='z_dc (Low-pass)', linestyle='--')
ax3.plot(z_ac, label='z_ac (High-pass)', linestyle=':')
ax3.set_title('z Time Series')
ax3.legend()

plt.tight_layout()
plt.show()

#Menyimpan hasil ke dalam CSV (untuk setiap time series)
header = 'Time, x_b, x_dc, x_ac, y_b, y_dc, y_ac, z_b, z_dc, z_ac'

#Menggabungkan data dalam satu file CSV
output_data = pd.DataFrame({
    'Time': np.arange(len(x_data)),  # Waktu dalam bentuk indeks
    'x_b': x_b, 'x_dc': x_dc, 'x_ac': x_ac,
    'y_b': y_b, 'y_dc': y_dc, 'y_ac': y_ac,
    'z_b': z_b, 'z_dc': z_dc, 'z_ac': z_ac
})

#Menyimpan ke dalam file CSV
output_data.to_csv(r'D:\Output HW 7 Slide 4-6\6.csv', index=False, header=True)

# %%
sn = pd.read_csv('7.csv')
print(f'Nama Kolom: {sn.columns}')
# Out:
# Nama Kolom: Index(['0', '1892', '2279', '1781', '1'], dtype='object')

# %%
#Memilih kolom yang sesuai dengan dataset
x_data = sn['1892']  
y_data = sn['2279']  
z_data = sn['1781']  

#Mmenerapkan low-pass dan high-pass filter
def butter_filter(data, cutoff, fs, btype='low'):
    nyquist = 0.5 * fs
    normal_cutoff = cutoff / nyquist
    b, a = butter(1, normal_cutoff, btype=btype, analog=False)
    return filtfilt(b, a, data)

#Frekuensi sampling dan frekuensi cutoff 
fs = 1000  
cutoff = 1  

#Menerapkan filter pada setiap data
x_b = x_data
x_dc = butter_filter(x_b, cutoff, fs, btype='low')  
x_ac = butter_filter(x_b, cutoff, fs, btype='high')  

y_b = y_data
y_dc = butter_filter(y_b, cutoff, fs, btype='low')
y_ac = butter_filter(y_b, cutoff, fs, btype='high')

z_b = z_data
z_dc = butter_filter(z_b, cutoff, fs, btype='low')
z_ac = butter_filter(z_b, cutoff, fs, btype='high')

#Plotting hasil analisis
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 5))
#Plot untuk x data
ax1.plot(x_b, label='x_b (No Filter)')
ax1.plot(x_dc, label='x_dc (Low-pass)', linestyle='--')
ax1.plot(x_ac, label='x_ac (High-pass)', linestyle=':')
ax1.set_title('x Time Series')
ax1.legend()

#Plot untuk y data
ax2.plot(y_b, label='y_b (No Filter)')
ax2.plot(y_dc, label='y_dc (Low-pass)', linestyle='--')
ax2.plot(y_ac, label='y_ac (High-pass)', linestyle=':')
ax2.set_title('y Time Series')
ax2.legend()

#Plot untuk z data
ax3.plot(z_b, label='z_b (No Filter)')
ax3.plot(z_dc, label='z_dc (Low-pass)', linestyle='--')
ax3.plot(z_ac, label='z_ac (High-pass)', linestyle=':')
ax3.set_title('z Time Series')
ax3.legend()

plt.tight_layout()
plt.show()

#Menyimpan hasil ke dalam CSV (untuk setiap time series)
header = 'Time, x_b, x_dc, x_ac, y_b, y_dc, y_ac, z_b, z_dc, z_ac'

#Menggabungkan data dalam satu file CSV
output_data = pd.DataFrame({
    'Time': np.arange(len(x_data)),  # Waktu dalam bentuk indeks
    'x_b': x_b, 'x_dc': x_dc, 'x_ac': x_ac,
    'y_b': y_b, 'y_dc': y_dc, 'y_ac': y_ac,
    'z_b': z_b, 'z_dc': z_dc, 'z_ac': z_ac
})

#Menyimpan ke dalam file CSV
output_data.to_csv(r'D:\Output HW 7 Slide 4-6\7.csv', index=False, header=True)

# %%
sn = pd.read_csv('8.csv')
print(f'Nama Kolom: {sn.columns}')
# Out:
# Nama Kolom: Index(['0', '2057', '2043', '1665', '1'], dtype='object')

# %%
#Memilih kolom yang sesuai dengan dataset
x_data = sn['2057']  
y_data = sn['2043']  
z_data = sn['1665']  

#Mmenerapkan low-pass dan high-pass filter
def butter_filter(data, cutoff, fs, btype='low'):
    nyquist = 0.5 * fs
    normal_cutoff = cutoff / nyquist
    b, a = butter(1, normal_cutoff, btype=btype, analog=False)
    return filtfilt(b, a, data)

#Frekuensi sampling dan frekuensi cutoff 
fs = 1000  
cutoff = 1  

#Menerapkan filter pada setiap data
x_b = x_data
x_dc = butter_filter(x_b, cutoff, fs, btype='low')  
x_ac = butter_filter(x_b, cutoff, fs, btype='high')  

y_b = y_data
y_dc = butter_filter(y_b, cutoff, fs, btype='low')
y_ac = butter_filter(y_b, cutoff, fs, btype='high')

z_b = z_data
z_dc = butter_filter(z_b, cutoff, fs, btype='low')
z_ac = butter_filter(z_b, cutoff, fs, btype='high')

#Plotting hasil analisis
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 5))
#Plot untuk x data
ax1.plot(x_b, label='x_b (No Filter)')
ax1.plot(x_dc, label='x_dc (Low-pass)', linestyle='--')
ax1.plot(x_ac, label='x_ac (High-pass)', linestyle=':')
ax1.set_title('x Time Series')
ax1.legend()

#Plot untuk y data
ax2.plot(y_b, label='y_b (No Filter)')
ax2.plot(y_dc, label='y_dc (Low-pass)', linestyle='--')
ax2.plot(y_ac, label='y_ac (High-pass)', linestyle=':')
ax2.set_title('y Time Series')
ax2.legend()

#Plot untuk z data
ax3.plot(z_b, label='z_b (No Filter)')
ax3.plot(z_dc, label='z_dc (Low-pass)', linestyle='--')
ax3.plot(z_ac, label='z_ac (High-pass)', linestyle=':')
ax3.set_title('z Time Series')
ax3.legend()

plt.tight_layout()
plt.show()

#Menyimpan hasil ke dalam CSV (untuk setiap time series)
header = 'Time, x_b, x_dc, x_ac, y_b, y_dc, y_ac, z_b, z_dc, z_ac'

#Menggabungkan data dalam satu file CSV
output_data = pd.DataFrame({
    'Time': np.arange(len(x_data)),  # Waktu dalam bentuk indeks
    'x_b': x_b, 'x_dc': x_dc, 'x_ac': x_ac,
    'y_b': y_b, 'y_dc': y_dc, 'y_ac': y_ac,
    'z_b': z_b, 'z_dc': z_dc, 'z_ac': z_ac
})
#Menyimpan ke dalam file CSV
output_data.to_csv(r'D:\Output HW 7 Slide 4-6\8.csv', index=False, header=True)

# %%
sn = pd.read_csv('9.csv')
print(f'Nama Kolom: {sn.columns}')
# Out:
# Nama Kolom: Index(['0', '2287', '2948', '2189', '1'], dtype='object')

# %%
#Memilih kolom yang sesuai dengan dataset
x_data = sn['2287']  
y_data = sn['2948']  
z_data = sn['2189']  

#Mmenerapkan low-pass dan high-pass filter
def butter_filter(data, cutoff, fs, btype='low'):
    nyquist = 0.5 * fs
    normal_cutoff = cutoff / nyquist
    b, a = butter(1, normal_cutoff, btype=btype, analog=False)
    return filtfilt(b, a, data)

#Frekuensi sampling dan frekuensi cutoff 
fs = 1000  
cutoff = 1  

#Menerapkan filter pada setiap data
x_b = x_data
x_dc = butter_filter(x_b, cutoff, fs, btype='low')  
x_ac = butter_filter(x_b, cutoff, fs, btype='high')  

y_b = y_data
y_dc = butter_filter(y_b, cutoff, fs, btype='low')
y_ac = butter_filter(y_b, cutoff, fs, btype='high')

z_b = z_data
z_dc = butter_filter(z_b, cutoff, fs, btype='low')
z_ac = butter_filter(z_b, cutoff, fs, btype='high')

#Plotting hasil analisis
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 5))

#Plot untuk x data
ax1.plot(x_b, label='x_b (No Filter)')
ax1.plot(x_dc, label='x_dc (Low-pass)', linestyle='--')
ax1.plot(x_ac, label='x_ac (High-pass)', linestyle=':')
ax1.set_title('x Time Series')
ax1.legend()

#Plot untuk y data
ax2.plot(y_b, label='y_b (No Filter)')
ax2.plot(y_dc, label='y_dc (Low-pass)', linestyle='--')
ax2.plot(y_ac, label='y_ac (High-pass)', linestyle=':')
ax2.set_title('y Time Series')
ax2.legend()

#Plot untuk z data
ax3.plot(z_b, label='z_b (No Filter)')
ax3.plot(z_dc, label='z_dc (Low-pass)', linestyle='--')
ax3.plot(z_ac, label='z_ac (High-pass)', linestyle=':')
ax3.set_title('z Time Series')
ax3.legend()

plt.tight_layout()
plt.show()

#Menyimpan hasil ke dalam CSV (untuk setiap time series)
header = 'Time, x_b, x_dc, x_ac, y_b, y_dc, y_ac, z_b, z_dc, z_ac'

#Menggabungkan data dalam satu file CSV
output_data = pd.DataFrame({
    'Time': np.arange(len(x_data)),  # Waktu dalam bentuk indeks
    'x_b': x_b, 'x_dc': x_dc, 'x_ac': x_ac,
    'y_b': y_b, 'y_dc': y_dc, 'y_ac': y_ac,
    'z_b': z_b, 'z_dc': z_dc, 'z_ac': z_ac
})

#Menyimpan ke dalam file CSV
output_data.to_csv(r'D:\Output HW 7 Slide 4-6\9.csv', index=False, header=True)

# %%
sn = pd.read_csv('10.csv')
print(f'Nama Kolom: {sn.columns}')
# Out:
# Nama Kolom: Index(['0', '2082', '2165', '1702', '1'], dtype='object')

# %%
#Memilih kolom yang sesuai dengan dataset
x_data = sn['2082']  
y_data = sn['2165']  
z_data = sn['1702']  

#Mmenerapkan low-pass dan high-pass filter
def butter_filter(data, cutoff, fs, btype='low'):
    nyquist = 0.5 * fs
    normal_cutoff = cutoff / nyquist
    b, a = butter(1, normal_cutoff, btype=btype, analog=False)
    return filtfilt(b, a, data)

#Frekuensi sampling dan frekuensi cutoff 
fs = 1000  
cutoff = 1  

#Menerapkan filter pada setiap data
x_b = x_data
x_dc = butter_filter(x_b, cutoff, fs, btype='low')  
x_ac = butter_filter(x_b, cutoff, fs, btype='high')  

y_b = y_data
y_dc = butter_filter(y_b, cutoff, fs, btype='low')
y_ac = butter_filter(y_b, cutoff, fs, btype='high')

z_b = z_data
z_dc = butter_filter(z_b, cutoff, fs, btype='low')
z_ac = butter_filter(z_b, cutoff, fs, btype='high')

#Plotting hasil analisis
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 5))
#Plot untuk x data
ax1.plot(x_b, label='x_b (No Filter)')
ax1.plot(x_dc, label='x_dc (Low-pass)', linestyle='--')
ax1.plot(x_ac, label='x_ac (High-pass)', linestyle=':')
ax1.set_title('x Time Series')
ax1.legend()

#Plot untuk y data
ax2.plot(y_b, label='y_b (No Filter)')
ax2.plot(y_dc, label='y_dc (Low-pass)', linestyle='--')
ax2.plot(y_ac, label='y_ac (High-pass)', linestyle=':')
ax2.set_title('y Time Series')
ax2.legend()

#Plot untuk z data
ax3.plot(z_b, label='z_b (No Filter)')
ax3.plot(z_dc, label='z_dc (Low-pass)', linestyle='--')
ax3.plot(z_ac, label='z_ac (High-pass)', linestyle=':')
ax3.set_title('z Time Series')
ax3.legend()

plt.tight_layout()
plt.show()

#Menyimpan hasil ke dalam CSV (untuk setiap time series)
header = 'Time, x_b, x_dc, x_ac, y_b, y_dc, y_ac, z_b, z_dc, z_ac'

#Menggabungkan data dalam satu file CSV
output_data = pd.DataFrame({
    'Time': np.arange(len(x_data)),  # Waktu dalam bentuk indeks
    'x_b': x_b, 'x_dc': x_dc, 'x_ac': x_ac,
    'y_b': y_b, 'y_dc': y_dc, 'y_ac': y_ac,
    'z_b': z_b, 'z_dc': z_dc, 'z_ac': z_ac
})

#Menyimpan ke dalam file CSV
output_data.to_csv(r'D:\Output HW 7 Slide 4-6\10.csv', index=False, header=True)

# %%
sn = pd.read_csv('11.csv')
print(f'Nama Kolom: {sn.columns}')
# Out:
# Nama Kolom: Index(['0', '1983', '2438', '1825', '1'], dtype='object')

# %%
#Memilih kolom yang sesuai dengan dataset
x_data = sn['1983']  
y_data = sn['2438']  
z_data = sn['1825']  

#Mmenerapkan low-pass dan high-pass filter
def butter_filter(data, cutoff, fs, btype='low'):
    nyquist = 0.5 * fs
    normal_cutoff = cutoff / nyquist
    b, a = butter(1, normal_cutoff, btype=btype, analog=False)
    return filtfilt(b, a, data)

#Frekuensi sampling dan frekuensi cutoff 
fs = 1000  
cutoff = 1  

#Menerapkan filter pada setiap data
x_b = x_data
x_dc = butter_filter(x_b, cutoff, fs, btype='low')  
x_ac = butter_filter(x_b, cutoff, fs, btype='high')  

y_b = y_data
y_dc = butter_filter(y_b, cutoff, fs, btype='low')
y_ac = butter_filter(y_b, cutoff, fs, btype='high')

z_b = z_data
z_dc = butter_filter(z_b, cutoff, fs, btype='low')
z_ac = butter_filter(z_b, cutoff, fs, btype='high')

#Plotting hasil analisis
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 5))
#Plot untuk x data
ax1.plot(x_b, label='x_b (No Filter)')
ax1.plot(x_dc, label='x_dc (Low-pass)', linestyle='--')
ax1.plot(x_ac, label='x_ac (High-pass)', linestyle=':')
ax1.set_title('x Time Series')
ax1.legend()

#Plot untuk y data
ax2.plot(y_b, label='y_b (No Filter)')
ax2.plot(y_dc, label='y_dc (Low-pass)', linestyle='--')
ax2.plot(y_ac, label='y_ac (High-pass)', linestyle=':')
ax2.set_title('y Time Series')
ax2.legend()

#Plot untuk z data
ax3.plot(z_b, label='z_b (No Filter)')
ax3.plot(z_dc, label='z_dc (Low-pass)', linestyle='--')
ax3.plot(z_ac, label='z_ac (High-pass)', linestyle=':')
ax3.set_title('z Time Series')
ax3.legend()

plt.tight_layout()
plt.show()

#Menyimpan hasil ke dalam CSV (untuk setiap time series)
header = 'Time, x_b, x_dc, x_ac, y_b, y_dc, y_ac, z_b, z_dc, z_ac'

#Menggabungkan data dalam satu file CSV
output_data = pd.DataFrame({
    'Time': np.arange(len(x_data)),  # Waktu dalam bentuk indeks
    'x_b': x_b, 'x_dc': x_dc, 'x_ac': x_ac,
    'y_b': y_b, 'y_dc': y_dc, 'y_ac': y_ac,
    'z_b': z_b, 'z_dc': z_dc, 'z_ac': z_ac
})

#Menyimpan ke dalam file CSV
output_data.to_csv(r'D:\Output HW 7 Slide 4-6\11.csv', index=False, header=True)

# %%
sn = pd.read_csv('12.csv')
print(f'Nama Kolom: {sn.columns}')
# Out:
# Nama Kolom: Index(['0', '1922', '2388', '1898', '1'], dtype='object')

# %%
#Memilih kolom yang sesuai dengan dataset
x_data = sn['1922']  
y_data = sn['2388']  
z_data = sn['1898']  

#Mmenerapkan low-pass dan high-pass filter
def butter_filter(data, cutoff, fs, btype='low'):
    nyquist = 0.5 * fs
    normal_cutoff = cutoff / nyquist
    b, a = butter(1, normal_cutoff, btype=btype, analog=False)
    return filtfilt(b, a, data)

#Frekuensi sampling dan frekuensi cutoff 
fs = 1000  
cutoff = 1  

#Menerapkan filter pada setiap data
x_b = x_data
x_dc = butter_filter(x_b, cutoff, fs, btype='low')  
x_ac = butter_filter(x_b, cutoff, fs, btype='high')  

y_b = y_data
y_dc = butter_filter(y_b, cutoff, fs, btype='low')
y_ac = butter_filter(y_b, cutoff, fs, btype='high')

z_b = z_data
z_dc = butter_filter(z_b, cutoff, fs, btype='low')
z_ac = butter_filter(z_b, cutoff, fs, btype='high')

#Plotting hasil analisis
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 5))
#Plot untuk x data
ax1.plot(x_b, label='x_b (No Filter)')
ax1.plot(x_dc, label='x_dc (Low-pass)', linestyle='--')
ax1.plot(x_ac, label='x_ac (High-pass)', linestyle=':')
ax1.set_title('x Time Series')
ax1.legend()

#Plot untuk y data
ax2.plot(y_b, label='y_b (No Filter)')
ax2.plot(y_dc, label='y_dc (Low-pass)', linestyle='--')
ax2.plot(y_ac, label='y_ac (High-pass)', linestyle=':')
ax2.set_title('y Time Series')
ax2.legend()

#Plot untuk z data
ax3.plot(z_b, label='z_b (No Filter)')
ax3.plot(z_dc, label='z_dc (Low-pass)', linestyle='--')
ax3.plot(z_ac, label='z_ac (High-pass)', linestyle=':')
ax3.set_title('z Time Series')
ax3.legend()

plt.tight_layout()
plt.show()

#Menyimpan hasil ke dalam CSV (untuk setiap time series)
header = 'Time, x_b, x_dc, x_ac, y_b, y_dc, y_ac, z_b, z_dc, z_ac'

#Menggabungkan data dalam satu file CSV
output_data = pd.DataFrame({
    'Time': np.arange(len(x_data)),  # Waktu dalam bentuk indeks
    'x_b': x_b, 'x_dc': x_dc, 'x_ac': x_ac,
    'y_b': y_b, 'y_dc': y_dc, 'y_ac': y_ac,
    'z_b': z_b, 'z_dc': z_dc, 'z_ac': z_ac
})

#Menyimpan ke dalam file CSV
output_data.to_csv(r'D:\Output HW 7 Slide 4-6\12.csv', index=False, header=True)

# %%
sn = pd.read_csv('13.csv')
print(f'Nama Kolom: {sn.columns}')
# Out:
# Nama Kolom: Index(['0', '1820', '2181', '1589', '1'], dtype='object')

# %%
#Memilih kolom yang sesuai dengan dataset
x_data = sn['1820']  
y_data = sn['2181']  
z_data = sn['1589']  

#Mmenerapkan low-pass dan high-pass filter
def butter_filter(data, cutoff, fs, btype='low'):
    nyquist = 0.5 * fs
    normal_cutoff = cutoff / nyquist
    b, a = butter(1, normal_cutoff, btype=btype, analog=False)
    return filtfilt(b, a, data)

#Frekuensi sampling dan frekuensi cutoff 
fs = 1000  
cutoff = 1  

#Menerapkan filter pada setiap data
x_b = x_data
x_dc = butter_filter(x_b, cutoff, fs, btype='low')  
x_ac = butter_filter(x_b, cutoff, fs, btype='high')  

y_b = y_data
y_dc = butter_filter(y_b, cutoff, fs, btype='low')
y_ac = butter_filter(y_b, cutoff, fs, btype='high')

z_b = z_data
z_dc = butter_filter(z_b, cutoff, fs, btype='low')
z_ac = butter_filter(z_b, cutoff, fs, btype='high')

#Plotting hasil analisis
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 5))
#Plot untuk x data
ax1.plot(x_b, label='x_b (No Filter)')
ax1.plot(x_dc, label='x_dc (Low-pass)', linestyle='--')
ax1.plot(x_ac, label='x_ac (High-pass)', linestyle=':')
ax1.set_title('x Time Series')
ax1.legend()

#Plot untuk y data
ax2.plot(y_b, label='y_b (No Filter)')
ax2.plot(y_dc, label='y_dc (Low-pass)', linestyle='--')
ax2.plot(y_ac, label='y_ac (High-pass)', linestyle=':')
ax2.set_title('y Time Series')
ax2.legend()

#Plot untuk z data
ax3.plot(z_b, label='z_b (No Filter)')
ax3.plot(z_dc, label='z_dc (Low-pass)', linestyle='--')
ax3.plot(z_ac, label='z_ac (High-pass)', linestyle=':')
ax3.set_title('z Time Series')
ax3.legend()

plt.tight_layout()
plt.show()

#Menyimpan hasil ke dalam CSV (untuk setiap time series)
header = 'Time, x_b, x_dc, x_ac, y_b, y_dc, y_ac, z_b, z_dc, z_ac'

#Menggabungkan data dalam satu file CSV
output_data = pd.DataFrame({
    'Time': np.arange(len(x_data)),  # Waktu dalam bentuk indeks
    'x_b': x_b, 'x_dc': x_dc, 'x_ac': x_ac,
    'y_b': y_b, 'y_dc': y_dc, 'y_ac': y_ac,
    'z_b': z_b, 'z_dc': z_dc, 'z_ac': z_ac
})

#Menyimpan ke dalam file CSV
output_data.to_csv(r'D:\Output HW 7 Slide 4-6\13.csv', index=False, header=True)

# %%
sn = pd.read_csv('14.csv')
print(f'Nama Kolom: {sn.columns}')
# Out:
# Nama Kolom: Index(['0', '1955', '2302', '1766', '1'], dtype='object')

# %%
#Memilih kolom yang sesuai dengan dataset
x_data = sn['1955']  
y_data = sn['2302']  
z_data = sn['1766']  

#Mmenerapkan low-pass dan high-pass filter
def butter_filter(data, cutoff, fs, btype='low'):
    nyquist = 0.5 * fs
    normal_cutoff = cutoff / nyquist
    b, a = butter(1, normal_cutoff, btype=btype, analog=False)
    return filtfilt(b, a, data)

#Frekuensi sampling dan frekuensi cutoff 
fs = 1000  
cutoff = 1  

#Menerapkan filter pada setiap data
x_b = x_data
x_dc = butter_filter(x_b, cutoff, fs, btype='low')  
x_ac = butter_filter(x_b, cutoff, fs, btype='high')  

y_b = y_data
y_dc = butter_filter(y_b, cutoff, fs, btype='low')
y_ac = butter_filter(y_b, cutoff, fs, btype='high')

z_b = z_data
z_dc = butter_filter(z_b, cutoff, fs, btype='low')
z_ac = butter_filter(z_b, cutoff, fs, btype='high')

#Plotting hasil analisis
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 5))
#Plot untuk x data
ax1.plot(x_b, label='x_b (No Filter)')
ax1.plot(x_dc, label='x_dc (Low-pass)', linestyle='--')
ax1.plot(x_ac, label='x_ac (High-pass)', linestyle=':')
ax1.set_title('x Time Series')
ax1.legend()

#Plot untuk y data
ax2.plot(y_b, label='y_b (No Filter)')
ax2.plot(y_dc, label='y_dc (Low-pass)', linestyle='--')
ax2.plot(y_ac, label='y_ac (High-pass)', linestyle=':')
ax2.set_title('y Time Series')
ax2.legend()

#Plot untuk z data
ax3.plot(z_b, label='z_b (No Filter)')
ax3.plot(z_dc, label='z_dc (Low-pass)', linestyle='--')
ax3.plot(z_ac, label='z_ac (High-pass)', linestyle=':')
ax3.set_title('z Time Series')
ax3.legend()

plt.tight_layout()
plt.show()

#Menyimpan hasil ke dalam CSV (untuk setiap time series)
header = 'Time, x_b, x_dc, x_ac, y_b, y_dc, y_ac, z_b, z_dc, z_ac'

#Menggabungkan data dalam satu file CSV
output_data = pd.DataFrame({
    'Time': np.arange(len(x_data)),  # Waktu dalam bentuk indeks
    'x_b': x_b, 'x_dc': x_dc, 'x_ac': x_ac,
    'y_b': y_b, 'y_dc': y_dc, 'y_ac': y_ac,
    'z_b': z_b, 'z_dc': z_dc, 'z_ac': z_ac
})

#Menyimpan ke dalam file CSV
output_data.to_csv(r'D:\Output HW 7 Slide 4-6\14.csv', index=False, header=True)

# %%
sn = pd.read_csv('15.csv')
print(f'Nama Kolom: {sn.columns}')
